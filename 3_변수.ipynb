# %% [markdown]
# # **1. 변수**

# %% [markdown]
# - 변수란 처리할 데이터를 저장시키는 기억장소

# %%
# = : 대입연산자
# 대입연산자 앞에 변수가 있다면 저장공간!
name = '류호근'
age = 22

# 그 외에는 전부 다 저장되어있는 값으로 쓰임.
print(name)
print(age)

# 이미 선언된 변수가 있다면 값을 덮어쓴다.
name = '홍길동'
print(name)
# Out:
# 류호근
# 22
# 홍길동

# %%
num1 = 10
num2 = 3

print('%d / %d = %.2f' % (num1, num2, num1/num2))
# Out:
# 10 / 3 = 3.33

# %% [markdown]
# # **2. 변수의 이름을 작성하는 방법**

# %% [markdown]
# - 값을 나타내는 핵심단어
# - 반드시 문자로 시작하고 예약어(키워드)는 사용할 수 없음 (이미 쓰임이 있는 단어)
# - 영문자, 숫자, 특수문자(_)로 사용하며 대소문자를 구별

# %% [markdown]
# # **3. 변수의 데이터 타입**

# %% [markdown]
# - 데이터 타입(자료형) : 자료가 저장되는 형태를 의미

# %%
name = '홍길동'
age = 25
weight = 65.5
isLover = True # False 는 앞글자가 대문자!

# type() : 변수의 데이터 타입을 반환해주는 함수
print(type(name)) # <class 'str'> -> string, 문자
print(type(age)) # <class 'int'> -> 정수
print(type(weight)) # <class 'float'> -> 실수
print(type(isLover)) # <class 'bool'> -> boolean, 논리, 참, 거짓
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(isLover)
# Out:
# True

# %%
# 변수를 삭제
del isLover

# %%
print(isLover)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-6053910d0aff> in <cell line: 1>()
# ----> 1 print(isLover)
#
# NameError: name 'isLover' is not defined
